# %% [markdown]
# # Practice of Basic NLP pre-processing using spaCy
#  - Reference https://ungodly-hour.tistory.com/37

# %% [markdown]
# # 0. Setting

# %% [markdown]
# ##### 0) 패키지 설치

# %%
# !pip install spacy
# !python -m spacy download xx_sent_ud_sm
# !python -m spacy download en_core_web_md
# Out:
# Collecting spacy
#   Downloading spacy-3.5.1-cp39-cp39-win_amd64.whl (12.2 MB)
#      --------------------------------------- 12.2/12.2 MB 46.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy) (4.64.1)
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.1-py3-none-any.whl (27 kB)
# Collecting typer<0.8.0,>=0.3.0
#   Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: setuptools in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy) (65.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy) (22.0)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.8-py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy) (1.21.5)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.4-py3-none-any.whl (11 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.7-cp39-cp39-win_amd64.whl (30 kB)
# Collecting thinc<8.2.0,>=8.1.8
#   Downloading thinc-8.1.9-cp39-cp39-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 18.8 MB/s eta 0:00:00
# Collecting langcodes<4.0.0,>=3.2.0
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# Requirement already satisfied: jinja2 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy) (3.1.2)
# Collecting pathy>=0.10.0
#   Downloading pathy-0.10.1-py3-none-any.whl (48 kB)
#      ---------------------------------------- 48.9/48.9 kB ? eta 0:00:00
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.8-cp39-cp39-win_amd64.whl (96 kB)
#      ---------------------------------------- 96.8/96.8 kB ? eta 0:00:00
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.6-cp39-cp39-win_amd64.whl (482 kB)
#      ------------------------------------- 482.8/482.8 kB 29.5 MB/s eta 0:00:00
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.9-cp39-cp39-win_amd64.whl (18 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4
#   Downloading pydantic-1.10.7-cp39-cp39-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 23.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.9-cp39-cp39-win_amd64.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 26.4 MB/s eta 0:00:00
# Collecting confection<1.0.0,>=0.0.1
#   Downloading confection-0.0.4-py3-none-any.whl (32 kB)
# Requirement already satisfied: colorama in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from jinja2->spacy) (2.1.1)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, pydantic, murmurhash, langcodes, catalogue, blis, typer, srsly, preshed, pathy, confection, thinc, spacy
# Successfully installed blis-0.7.9 catalogue-2.0.8 confection-0.0.4 cymem-2.0.7 langcodes-3.3.0 murmurhash-1.0.9 pathy-0.10.1 preshed-3.0.8 pydantic-1.10.7 spacy-3.5.1 spacy-legacy-3.0.12 spacy-loggers-1.0.4 srsly-2.4.6 thinc-8.1.9 typer-0.7.0 wasabi-1.1.1
# Collecting xx-sent-ud-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/xx_sent_ud_sm-3.5.0/xx_sent_ud_sm-3.5.0-py3-none-any.whl (4.3 MB)
#      ---------------------------------------- 4.3/4.3 MB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from xx-sent-ud-sm==3.5.0) (3.5.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (8.1.9)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (2.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (2.28.1)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (1.10.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (4.64.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (2.0.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (22.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (1.0.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (5.2.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (3.0.12)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (2.4.6)
# Requirement already satisfied: setuptools in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (65.6.3)
# Requirement already satisfied: jinja2 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (3.1.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (1.1.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (1.21.5)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (0.10.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (2.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (0.0.4)
# Requirement already satisfied: colorama in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->xx-sent-ud-sm==3.5.0) (2.1.1)
# Installing collected packages: xx-sent-ud-sm
# Successfully installed xx-sent-ud-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('xx_sent_ud_sm')
# Collecting en-core-web-md==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.5.0/en_core_web_md-3.5.0-py3-none-any.whl (42.8 MB)
#      --------------------------------------- 42.8/42.8 MB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from en-core-web-md==3.5.0) (3.5.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.0.4)
# Requirement already satisfied: jinja2 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (22.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.10.7)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (5.2.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.4.6)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.10.1)
# Requirement already satisfied: setuptools in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (65.6.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.28.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.1.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (8.1.9)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.7.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.0.12)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.0.9)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.21.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (4.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.0.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.7.9)
# Requirement already satisfied: colorama in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (8.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-md==3.5.0) (2.1.1)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %% [markdown]
# # 1. Tokenization

# %%
# 0) 라이브러리 불러오기
import spacy

# 1) 데이터 불러오기
text = 'I have studied at Ecole Normal Superieure (ENS) In Paris, Leipzig University in Germany, and KAIST in Korea during my Ph.D and Master.'

# 2) Tokenization 모델 불러오기
nlp = spacy.load('en_core_web_md') # !!!
# 3) Tokenization 수행
doc = nlp(text)
tokenized = list(doc)

# 4) 결과 출력
print(tokenized)
# Out:
# [I, have, studied, at, Ecole, Normal, Superieure, (, ENS, ), In, Paris, ,, Leipzig, University, in, Germany, ,, and, KAIST, in, Korea, during, my, Ph, ., D, and, Master, .]

# %% [markdown]
# # 2. POS tagging and Dependency

# %%
# 0) 라이브러리 불러오기
import spacy

# 1) 데이터 불러오기
text = 'text = "Sejong of Joseon (15 May 1397 – 8 April 1450), personal name Yi Do (Korean: 이도; Hanja: 李祹), widely known as Sejong the Great (Korean: 세종대왕; Hanja: 世宗大王), was the fourth ruler of the Joseon dynasty of Korea."'

# 2) Tokenization 모델 불러오기
nlp = spacy.load('en_core_web_md')
# 3) Tokenization 수행
doc = nlp(text)

# 4) POS Tagging
str_format = "{:>10}"*8 # !!!
print(str_format.format('Text', 'Lemma', 'POS', 'Tag', 'Dep', 'Shape', 'is alpha', 'is stop')) # !!!
print("=="*40)

for token in doc: # !!!
    print(str_format.format(token.text, token.lemma_, token.pos_, token.tag_, # !!!
                            token.dep_, token.shape_, str(token.is_alpha), str(token.is_stop)))
# Out:
#       Text     Lemma       POS       Tag       Dep     Shape  is alpha   is stop
# ================================================================================
#       text      text      NOUN        NN      ROOT      xxxx      True     False
#          =         =         X        FW     punct         =     False     False
#          "         "     PUNCT        ``     punct         "     False     False
#     Sejong    Sejong     PROPN       NNP     appos     Xxxxx      True     False
#         of        of       ADP        IN      prep        xx      True      True
#     Joseon    Joseon     PROPN       NNP      pobj     Xxxxx      True     False
#          (         (     PUNCT     -LRB-     punct         (     False     False
#         15        15       NUM        CD    nummod        dd     False     False
#        May       May     PROPN       NNP     appos       Xxx      True      True
#       1397      1397       NUM        CD    nummod      dddd     False     False
#          –         –     PUNCT         :     punct         –     False     False
#          8         8       NUM        CD    nummod         d     False     False
#      April     April     PROPN       NNP     appos     Xxxxx      True     False
#       1450      1450       NUM        CD    nummod      dddd     False     False
#          )         )     PUNCT     -RRB-     punct         )     False     False
#          ,         ,     PUNCT         ,     punct         ,     False     False
#   personal  personal       ADJ        JJ      amod      xxxx      True     False
#       name      name      NOUN        NN     appos      xxxx      True      True
#         Yi        Yi     PROPN       NNP  compound        Xx      True     False
#         Do        Do     PROPN       NNP       dep        Xx      True      True
#          (         (     PUNCT     -LRB-     punct         (     False     False
#     Korean    korean       ADJ        JJ       dep     Xxxxx      True     False
#          :         :     PUNCT         :     punct         :     False     False
#         이도        이도     PROPN       NNP     nsubj        xx      True     False
#          ;         ;     PUNCT         :     punct         ;     False     False
#      Hanja     Hanja     PROPN       NNP     appos     Xxxxx      True     False
#          :         :     PUNCT         :     punct         :     False     False
#         李祹        李祹     PROPN       NNP     appos        xx      True     False
#          )         )     PUNCT     -RRB-     punct         )     False     False
#          ,         ,     PUNCT         ,     punct         ,     False     False
#     widely    widely       ADV        RB    advmod      xxxx      True     False
#      known      know      VERB       VBN       acl      xxxx      True     False
#         as        as       ADP        IN      prep        xx      True      True
#     Sejong    Sejong     PROPN       NNP      pobj     Xxxxx      True     False
#        the       the       DET        DT       det       xxx      True      True
#      Great     great       ADJ        JJ      amod     Xxxxx      True     False
#          (         (     PUNCT     -LRB-     punct         (     False     False
#     Korean    korean       ADJ        JJ      amod     Xxxxx      True     False
#          :         :     PUNCT         :     punct         :     False     False
#       세종대왕      세종대왕      NOUN        NN     appos      xxxx      True     False
#          ;         ;     PUNCT         :     punct         ;     False     False
#      Hanja     Hanja     PROPN       NNP     appos     Xxxxx      True     False
#          :         :     PUNCT         :     punct         :     False     False
#       世宗大王      世宗大王     PROPN       NNP     appos      xxxx      True     False
#          )         )     PUNCT     -RRB-     punct         )     False     False
#          ,         ,     PUNCT         ,     punct         ,     False     False
#        was        be       AUX       VBD      ROOT       xxx      True      True
#        the       the       DET        DT       det       xxx      True      True
#     fourth    fourth       ADJ        JJ      amod      xxxx      True     False
#      ruler     ruler      NOUN        NN      attr      xxxx      True     False
#         of        of       ADP        IN      prep        xx      True      True
#        the       the       DET        DT       det       xxx      True      True
#     Joseon    Joseon     PROPN       NNP  compound     Xxxxx      True     False
#    dynasty   dynasty      NOUN        NN      pobj      xxxx      True     False
#         of        of       ADP        IN      prep        xx      True      True
#      Korea     Korea     PROPN       NNP      pobj     Xxxxx      True     False
#          .         .     PUNCT         .     punct         .     False     False
#          "         "     PUNCT        ''     punct         "     False     False

# %% [markdown]
# # 3. Stop words 제거

# %%
stopwords = spacy.lang.en.stop_words.STOP_WORDS
print(stopwords)
# Out:
# {'too', 'who', 'next', 'might', 'yourself', 'throughout', 'via', 'since', 'beforehand', 'first', 'something', 'hereafter', 'only', 'itself', 'moreover', 'wherever', 'does', 'again', 'to', 'both', 'used', 'others', '‘re', 'whereafter', 'nine', 'among', 'cannot', 'enough', 'our', 'must', 'n’t', 'which', 'sixty', 'also', 'twenty', 'how', 'every', 'see', 'further', 'except', 'ours', 'go', 'towards', 'ten', '‘s', 'twelve', 'made', 'anyone', 'whose', 'whereupon', "'re", 'whenever', 'you', '’re', 'into', 'though', 'noone', 'serious', 'whither', "'ll", 'please', 'whereby', 'be', 'back', 'seemed', 'ourselves', 'nor', 'whole', 'him', 'top', "'ve", "n't", 'least', 'should', "'m", 'may', 'each', 'herein', 'amongst', '’m', 'thus', 'nevertheless', 'sometime', 'hereby', "'s", 'have', 'hence', 'did', 'anywhere', 'an', 'besides', "'d", 'hers', 'a', 're', 'before', 'own', 'ever', 'they', 'beyond', 'above', 'whatever', 'well', 'otherwise', 'else', 'yet', 'eleven', 'hereupon', 'almost', 'behind', 'and', 'even', 'thru', 'give', 'about', 'between', 'his', 'mostly', 'seem', 'whoever', 'anyhow', 'in', 'indeed', 'for', 'move', 'himself', 'five', 'while', 'becomes', 'after', 'formerly', 'therefore', 'although', 'as', 'thereupon', 'against', 'rather', 'what', 'across', 'say', 'became', 'mine', 'along', 'no', 'sometimes', 'than', 'toward', 'becoming', '‘ll', '’d', 'by', 'never', 'however', 'myself', 'your', 'former', 'eight', 'until', 'them', 'such', 'due', 'make', 'somewhere', 'some', 'upon', 'same', 'using', 'side', 'call', 'thereafter', 'nobody', 'neither', 'being', 'six', 'done', 'of', 'unless', 'namely', '‘d', 'front', 'still', 'alone', 'when', 'everywhere', 'it', 'had', 'yourselves', 'full', 'much', 'amount', 'thereby', '‘m', 'empty', 'afterwards', 'seeming', 'take', 'show', 'name', '’ll', 'together', 'nothing', 'always', 'over', 'perhaps', 'elsewhere', 'part', 'everything', 'latterly', 'is', 'several', 'fifteen', 'there', 'more', '’s', 'get', 'during', 'last', 'forty', 'someone', 'less', 'regarding', 'those', 'if', '‘ve', 'seems', 'many', 'i', 'one', 'various', 'other', 'this', 'its', 'thence', 'whereas', 'now', 'the', 'do', 'will', 'hundred', 'just', 'nowhere', 'really', 'from', 'where', 'whence', 'he', 'has', 'with', 'that', 'below', 'up', 'any', 'once', 'why', 'at', 'doing', 'not', 'but', 'then', 'third', 'through', 'could', 'therein', 'without', 'wherein', 'their', 'ca', 'bottom', 'most', 'none', 'everyone', 'because', 'three', 'would', 'whom', 'another', 'was', 'keep', 'often', 'anyway', 'whether', 'latter', 'we', 'around', 'themselves', 'she', 'my', 'been', 'so', 'yours', 'either', 'meanwhile', 'within', 'under', 'are', 'me', 'off', 'these', '’ve', 'herself', 'already', 'beside', 'here', 'onto', 'am', 'quite', 'on', 'fifty', 'out', 'n‘t', 'somehow', 'per', 'down', 'or', 'were', 'all', 'her', 'anything', 'few', 'us', 'can', 'two', 'four', 'very', 'become', 'put'}

# %%
# 0) 라이브러리 불러오기
import spacy

# 1) 데이터 불러오기
text = 'I have studied at Ecole Normal Superieure (ENS) In Paris, Leipzig University in Germany, and KAIST in Korea during my Ph.D and Master.'

# 2) Tokenization 모델 불러오기
nlp = spacy.load('en_core_web_md')
# 3) Tokenization 수행
doc = nlp(text)

# 4) Stop Words 제거
filtered = []
for token in doc:
    if not token.is_stop: # !!!
        filtered.append(token)

# 5) 결과 출력
print(filtered)
# Out:
# [studied, Ecole, Normal, Superieure, (, ENS, ), Paris, ,, Leipzig, University, Germany, ,, KAIST, Korea, Ph, ., D, Master, .]

# %% [markdown]
# # 4. Dependency Parsing
#  - nlp() 메서드 결과물에 noun_chunks() 메소드를 호출하면, 자동으로 dependecy graph를 고려하여 noun phrase를 뽑아준다. (return 값은 Span 클래스의 generator)

# %%
# 0) 라이브러리 불러오기
import spacy

# 1) 데이터 불러오기
text = 'I have studied at Ecole Normal Superieure (ENS) In Paris, Leipzig University in Germany, and KAIST in Korea during my Ph.D and Master.'

# 2) Tokenization 모델 불러오기
nlp = spacy.load('en_core_web_md')
# 3) Tokenization 수행
doc = nlp(text)

# 4) Chunk Dependency Parsing
noun_chunks = doc.noun_chunks

print("=="*40)
str_format = "{:>30}{:>15}{:>15}{:>20}" # !!!
print(str_format.format('Text', 'Root Text', 'Root Dep', 'Root Head Text')) # !!!
print("=="*40)

for chunk in doc.noun_chunks: # !!!
    print(str_format.format(chunk.text, chunk.root.text, chunk.root.dep_, chunk.root.head.text)) # !!!
# Out:
# ================================================================================
#                           Text      Root Text       Root Dep      Root Head Text
# ================================================================================
#                              I              I          nsubj             studied
#        Ecole Normal Superieure     Superieure           pobj                  at
#                           (ENS            ENS          appos          Superieure
#                          Paris          Paris           pobj                  In
#                        Germany        Germany           pobj                  in
#                          KAIST          KAIST           conj          University
#                          Korea          Korea           pobj                  in
#                        my Ph.D              D           pobj              during
#                         Master         Master           conj                   D

# %% [markdown]
# # 5. Navigating Parse Tree

# %%
# 0) 라이브러리 불러오기
import spacy

# 1) 데이터 불러오기
text = 'I have studied at Ecole Normal Superieure (ENS) In Paris, Leipzig University in Germany, and KAIST in Korea during my Ph.D and Master.'

# 2) Tokenization 모델 불러오기
nlp = spacy.load('en_core_web_md')
# 3) Tokenization 수행
doc = nlp(text)

# 4) Navigating Parse Tree
for token in doc:
    print(token.text) # !!!
    children = list(token.children) # !!!
    print('children:', children, 'head:', token.head if token.head != token else "!this is root node") # !!!
    print("=="*28)
# Out:
# I
# children: [] head: studied
# ========================================================
# have
# children: [] head: studied
# ========================================================
# studied
# children: [I, have, at] head: !this is root node
# ========================================================
# at
# children: [Superieure] head: studied
# ========================================================
# Ecole
# children: [] head: Superieure
# ========================================================
# Normal
# children: [] head: Superieure
# ========================================================
# Superieure
# children: [Ecole, Normal, ENS, )] head: at
# ========================================================
# (
# children: [] head: ENS
# ========================================================
# ENS
# children: [(] head: Superieure
# ========================================================
# )
# children: [] head: Superieure
# ========================================================
# In
# children: [Paris] head: University
# ========================================================
# Paris
# children: [] head: In
# ========================================================
# ,
# children: [] head: University
# ========================================================
# Leipzig
# children: [] head: University
# ========================================================
# University
# children: [In, ,, Leipzig, in, ,, and, KAIST, .] head: !this is root node
# ========================================================
# in
# children: [Germany] head: University
# ========================================================
# Germany
# children: [] head: in
# ========================================================
# ,
# children: [] head: University
# ========================================================
# and
# children: [] head: University
# ========================================================
# KAIST
# children: [in, during] head: University
# ========================================================
# in
# children: [Korea] head: KAIST
# ========================================================
# Korea
# children: [] head: in
# ========================================================
# during
# children: [D] head: KAIST
# ========================================================
# my
# children: [] head: D
# ========================================================
# Ph
# children: [] head: D
# ========================================================
# .
# children: [] head: D
# ========================================================
# D
# children: [my, Ph, ., and, Master] head: during
# ========================================================
# and
# children: [] head: D
# ========================================================
# Master
# children: [] head: D
# ========================================================
# .
# children: [] head: University
# ========================================================

# %% [markdown]
# ## 6. Named Entity Recognition

# %%
# 0) 라이브러리 불러오기
import spacy

# 1) 데이터 불러오기
text = "Sejong of Joseon (15 May 1397 – 8 April 1450), personal name Yi Do (Korean: 이도; Hanja: 李祹), widely known as Sejong the Great (Korean: 세종대왕; Hanja: 世宗大王), was the fourth ruler of the Joseon dynasty of Korea."

# 2) Tokenization 모델 불러오기
nlp = spacy.load('en_core_web_md')
# 3) Tokenization 수행
doc = nlp(text)

# 4) Named Entity Recognition
print("="*40)
str_format = "{:>20}"*2
print(str_format.format('Text', 'NER'))
print("="*40)
for ent in doc.ents: # !!!
    print(str_format.format(ent.text, ent.label_)) # !!!
# Out:
# ========================================
#                 Text                 NER
# ========================================
#               Sejong              PERSON
#                   15            CARDINAL
#         8 April 1450                DATE
#                Yi Do              PERSON
#               Korean                NORP
#                Hanja              PERSON
#               Korean                NORP
#                Hanja              PERSON
#               fourth             ORDINAL
#   the Joseon dynasty                DATE
#                Korea                 GPE
