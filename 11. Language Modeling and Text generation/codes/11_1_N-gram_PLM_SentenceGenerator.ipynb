# %% [markdown]
# ## 실습 [11-1]
#
# ### 1. 실습명 : N-gram 언어 모델로 문장 생성하기
# ### 2. 실습 목적 및 설명
#
# *   파이썬의 NLTK 패키지를 이용하여 N-gram 언어 모델을 구축한다
# *   네이버에서 오픈 소스로 제공하는 nsmc 영화 리뷰 데이터셋을 이용해 문장을 생성한다.
#
# ### 3. 참조: 자연어처리바이블 9장

# %% [markdown]
# ##### 0) 라이브러리 불러오기

# %%
""" 이건 Ubuntu나 Colab 환경인듯
# 한국어 처리에 필요한 konlpy 패키지를 설치하기 전에 선행 파일을 설치한다. 
# !apt-get update

# !apt-get install g++ openjdk-8-jdk python-dev python3-dev

# !pip3 install JPype1-py3

# !pip3 install konlpy

# !JAVA_HOME="/usr/lib/jvm/java-8-openjdk-amd64"
"""
# Out:
# 'apt-get'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# 'apt-get'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# Requirement already satisfied: JPype1-py3 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (0.5.5.4)
# Requirement already satisfied: konlpy in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from konlpy) (1.4.1)
# Requirement already satisfied: numpy>=1.6 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from konlpy) (1.21.5)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from konlpy) (4.9.1)
# Requirement already satisfied: packaging in c:\users\bang\anaconda\envs\bangenv\lib\site-packages (from JPype1>=0.7.0->konlpy) (22.0)
# 'JAVA_HOME'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# (1) 기본 라이브러리
import random
import numpy as np
import codecs
from tqdm import tqdm
import urllib.request # !!

# (2) 자연어처리 라이브러리
import nltk
from nltk.util import ngrams # !!!
from nltk import word_tokenize # !!!
from nltk import ConditionalFreqDist # !!!
from nltk.probability import ConditionalProbDist, MLEProbDist # !!!

from konlpy.tag import Okt

nltk.download('punkt') # NLTK 사용을 위한 선행 패키지 설치
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Bang\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ##### 1) 데이터 불러오기

# %%
# (1) 데이터 불러오기
sentence = "나는 매일 아침 지하철을 탄다"

# %% [markdown]
# ##### 2) Tokenization

# %%
# (1) Tokenization : 띄어쓰기 기준 토큰화
sentence_nltk = word_tokenize(sentence)

print(f'sentence_nltk : {sentence_nltk}')
# Out:
# sentence_nltk : ['나는', '매일', '아침', '지하철을', '탄다']

# %%
# (1) Tokenization : 형태소 기준 토큰화 (한국어는 띄어쓰기 기준으로 단어를 쪼개지 않기 때문)
tagger = Okt()

def okt_tokenize(sentence):
  sentence_okt = ['/'.join(t) for t in tagger.pos(sentence)] # !!!
  # print(tagger.pos(sentence))
  return sentence_okt

sentence_okt = okt_tokenize(sentence)

print(f'sentence_okt : {sentence_okt}')
# Out:
# sentence_okt : ['나/Noun', '는/Josa', '매일/Noun', '아침/Noun', '지하철/Noun', '을/Josa', '탄다/Verb']

# %% [markdown]
# ##### 3) N-gram

# %% [markdown]
# (1) N-gram 변환

# %%
bigram = ngrams(sentence_okt, 2) # !!!
trigram = ngrams(sentence_okt, 3)

# %%
print("bigram: ")
for b in bigram:
  print(b)

print("\ntrigram: ")
for t in trigram:
  print(t)
# Out:
# bigram:
# ('나/Noun', '는/Josa')
# ('는/Josa', '매일/Noun')
# ('매일/Noun', '아침/Noun')
# ('아침/Noun', '지하철/Noun')
# ('지하철/Noun', '을/Josa')
# ('을/Josa', '탄다/Verb')
#
# trigram:
# ('나/Noun', '는/Josa', '매일/Noun')
# ('는/Josa', '매일/Noun', '아침/Noun')
# ('매일/Noun', '아침/Noun', '지하철/Noun')
# ('아침/Noun', '지하철/Noun', '을/Josa')
# ('지하철/Noun', '을/Josa', '탄다/Verb')

# %% [markdown]
# (2) Padding 추가 : 입력 데이터 시작, 끝을 알리는 토큰 추가

# %%
bigram = ngrams(sentence_okt, 2, pad_left=True, pad_right=True, left_pad_symbol="<s>", right_pad_symbol="</s>") # !!!

# %%
print("bigrams with padding: ")
for b in bigram:
  print(b)
# Out:
# bigrams with padding:
# ('<s>', '나/Noun')
# ('나/Noun', '는/Josa')
# ('는/Josa', '매일/Noun')
# ('매일/Noun', '아침/Noun')
# ('아침/Noun', '지하철/Noun')
# ('지하철/Noun', '을/Josa')
# ('을/Josa', '탄다/Verb')
# ('탄다/Verb', '</s>')

# %% [markdown]
# ##### 1) 데이터 불러오기
# - 네이버 영화 리뷰 데이터셋 다운로드

# %%
""" 이건 Ubuntu나 Colab 환경인듯
# %%time
# !wget -nc -q https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt
"""

urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt") # !!
# Out:
# ('ratings_train.txt', <http.client.HTTPMessage at 0x1d2ffa97dc0>)

# %% [markdown]
# ##### 2) 텍스트만 추출

# %%
with codecs.open("ratings_train.txt", encoding='utf-8') as f: # codecs 패키지 : 대용량 파일을 조금씩 읽을 수 있게 해줌 # !!!
  # (1) \n 기준 Lines Split + \t 기준 Line Split
  dataset = [line.split('\t') for line in f.read().splitlines()] # !!!
  # (2) Header 제외
  dataset = dataset[1:] # !!!

print("데이터셋 형식 : ", dataset[:10]) # [['9976970', '아 더빙.. 진짜 짜증나네요 목소리', '0'], ['3819312', '흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나', '1'], ['10265843', '너무재밓었다그래서보는것을추천한다', '0'], ['9045019', '교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정', '0'], ['6483659', '사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다', '1'], ['5403919', '막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.', '0'], ['7797314', '원작의 긴장감을 제대로 살려내지못했다.', '0'], ['9443947', '별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단 낫겟다 납치.감금만반복반복..이드라마는 가족도없다 연기못하는사람만모엿네', '0'], ['7156791', '액션이 없는데도 재미 있는 몇안되는 영화', '1'], ['5912145', '왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?', '1']]

# (3) 텍스트만 추출
sentences = [data[1] for data in dataset] # !!!

print("텍스트 데이터 : ", sentences[:5]) # ['아 더빙.. 진짜 짜증나네요 목소리', '흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나', '너무재밓었다그래서보는것을추천한다', '교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정', '사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다']
print("문장 개수 : ", len(sentences)) # 150000
# Out:
# 데이터셋 형식 :  [['9976970', '아 더빙.. 진짜 짜증나네요 목소리', '0'], ['3819312', '흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나', '1'], ['10265843', '너무재밓었다그래서보는것을추천한다', '0'], ['9045019', '교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정', '0'], ['6483659', '사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다', '1'], ['5403919', '막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.', '0'], ['7797314', '원작의 긴장감을 제대로 살려내지못했다.', '0'], ['9443947', '별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단 낫겟다 납치.감금만반복반복..이드라마는 가족도없다 연기못하는사람만모엿네', '0'], ['7156791', '액션이 없는데도 재미 있는 몇안되는 영화', '1'], ['5912145', '왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?', '1']]
# 텍스트 데이터 :  ['아 더빙.. 진짜 짜증나네요 목소리', '흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나', '너무재밓었다그래서보는것을추천한다', '교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정', '사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다']
# 문장 개수 :  150000

# %% [markdown]
# ##### 3) Tokenization + N-gram 변환

# %%
sentence_ngrams = []
for sentence in tqdm(sentences):
  sentence_okt = okt_tokenize(sentence) # !!
  bigram = ngrams(sentence_okt, 2, pad_left=True, pad_right=True, left_pad_symbol="<s>", right_pad_symbol="</s>") # !!
  sentence_ngrams += [b for b in bigram] # !!
# Out:
# 100%|██████████| 150000/150000 [04:19<00:00, 577.21it/s]

# %%
bigram
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 bigram.tolist()
#
# AttributeError: 'zip' object has no attribute 'tolist'

# %%
sentence_ngrams
# Out:
# [('<s>', '아/Exclamation'),
#  ('아/Exclamation', '더빙/Noun'),
#  ('더빙/Noun', '../Punctuation'),
#  ('../Punctuation', '진짜/Noun'),
#  ('진짜/Noun', '짜증나네요/Adjective'),
#  ('짜증나네요/Adjective', '목소리/Noun'),
#  ('목소리/Noun', '</s>'),
#  ('<s>', '흠/Noun'),
#  ('흠/Noun', '.../Punctuation'),
#  ('.../Punctuation', '포스터/Noun'),
#  ('포스터/Noun', '보고/Noun'),
#  ('보고/Noun', '초딩/Noun'),
#  ('초딩/Noun', '영화/Noun'),
#  ('영화/Noun', '줄/Noun'),
#  ('줄/Noun', '..../Punctuation'),
#  ('..../Punctuation', '오버/Noun'),
#  ('오버/Noun', '연기/Noun'),
#  ('연기/Noun', '조차/Josa'),
#  ('조차/Josa', '가볍지/Adjective'),
#  ('가볍지/Adjective', '않구나/Verb'),
#  ('않구나/Verb', '</s>'),
#  ('<s>', '너/Modifier'),
#  ('너/Modifier', '무재/Noun'),
#  ('무재/Noun', '밓었/Noun'),
#  ('밓었/Noun', '다그/Noun'),
#  ('다그/Noun', '래서/Noun'),
#  ('래서/Noun', '보는것을/Verb'),
#  ('보는것을/Verb', '추천/Noun'),
#  ('추천/Noun', '한/Josa'),
#  ('한/Josa', '다/Adverb'),
#  ('다/Adverb', '</s>'),
#  ('<s>', '교도소/Noun'),
#  ('교도소/Noun', '이야기/Noun'),
#  ('이야기/Noun', '구먼/Noun'),
#  ('구먼/Noun', '../Punctuation'),
#  ('../Punctuation', '솔직히/Adjective'),
#  ('솔직히/Adjective', '재미/Noun'),
#  ('재미/Noun', '는/Josa'),
#  ('는/Josa', '없다/Adjective'),
#  ('없다/Adjective', '../Punctuation'),
#  ('../Punctuation', '평점/Noun'),
#  ('평점/Noun', '조정/Noun'),
#  ('조정/Noun', '</s>'),
#  ('<s>', '사이/Modifier'),
#  ('사이/Modifier', '몬페/Noun'),
#  ('몬페/Noun', '그/Determiner'),
#  ('그/Determiner', '의/Noun'),
#  ('의/Noun', '익살스런/Adjective'),
#  ('익살스런/Adjective', '연기/Noun'),
#  ('연기/Noun', '가/Josa'),
#  ('가/Josa', '돋보였던/Verb'),
#  ('돋보였던/Verb', '영화/Noun'),
#  ('영화/Noun', '!/Punctuation'),
#  ('!/Punctuation', '스파이더맨/Noun'),
#  ('스파이더맨/Noun', '에서/Josa'),
#  ('에서/Josa', '늙어/Verb'),
#  ('늙어/Verb', '보이기만/Verb'),
#  ('보이기만/Verb', '했던/Verb'),
#  ('했던/Verb', '커스틴/Noun'),
#  ('커스틴/Noun', '던스트/Noun'),
#  ('던스트/Noun', '가/Josa'),
#  ('가/Josa', '너무나도/Adverb'),
#  ('너무나도/Adverb', '이뻐/Adjective'),
#  ('이뻐/Adjective', '보였다/Verb'),
#  ('보였다/Verb', '</s>'),
#  ('<s>', '막/Noun'),
#  ('막/Noun', '걸음/Noun'),
#  ('걸음/Noun', '마/Noun'),
#  ('마/Noun', '뗀/Verb'),
#  ('뗀/Verb', '3/Number'),
#  ('3/Number', '세/Noun'),
#  ('세/Noun', '부터/Josa'),
#  ('부터/Josa', '초등학교/Noun'),
#  ('초등학교/Noun', '1/Number'),
#  ('1/Number', '학년/Noun'),
#  ('학년/Noun', '생인/Noun'),
#  ('생인/Noun', '8/Number'),
#  ('8/Number', '살용/Verb'),
#  ('살용/Verb', '영화/Noun'),
#  ('영화/Noun', './Punctuation'),
#  ('./Punctuation', 'ㅋㅋㅋ/KoreanParticle'),
#  ('ㅋㅋㅋ/KoreanParticle', '.../Punctuation'),
#  ('.../Punctuation', '별/Modifier'),
#  ('별/Modifier', '반개/Noun'),
#  ('반개/Noun', '도/Josa'),
#  ('도/Josa', '아까/Adjective'),
#  ('아까/Adjective', '움/Noun'),
#  ('움/Noun', './Punctuation'),
#  ('./Punctuation', '</s>'),
#  ('<s>', '원작/Noun'),
#  ('원작/Noun', '의/Josa'),
#  ('의/Josa', '긴장감/Noun'),
#  ('긴장감/Noun', '을/Josa'),
#  ('을/Josa', '제대로/Noun'),
#  ('제대로/Noun', '살려내지못/Verb'),
#  ('살려내지못/Verb', '했다/Verb'),
#  ('했다/Verb', './Punctuation'),
#  ('./Punctuation', '</s>'),
#  ('<s>', '별/Noun'),
#  ('별/Noun', '반개/Noun'),
#  ('반개/Noun', '도/Josa'),
#  ('도/Josa', '아깝다/Adjective'),
#  ('아깝다/Adjective', '욕/Noun'),
#  ('욕/Noun', '나온다/Verb'),
#  ('나온다/Verb', '이응경/Noun'),
#  ('이응경/Noun', '길용우/Noun'),
#  ('길용우/Noun', '연/Modifier'),
#  ('연/Modifier', '기/Modifier'),
#  ('기/Modifier', '생활/Noun'),
#  ('생활/Noun', '이/Josa'),
#  ('이/Josa', '몇/Modifier'),
#  ('몇/Modifier', '년/Noun'),
#  ('년/Noun', '인지/Josa'),
#  ('인지/Josa', '../Punctuation'),
#  ('../Punctuation', '정말/Noun'),
#  ('정말/Noun', '발/Noun'),
#  ('발/Noun', '로/Josa'),
#  ('로/Josa', '해도/Noun'),
#  ('해도/Noun', '그것/Noun'),
#  ('그것/Noun', '보단/Josa'),
#  ('보단/Josa', '낫겟다/Verb'),
#  ('낫겟다/Verb', '납치/Noun'),
#  ('납치/Noun', './Punctuation'),
#  ('./Punctuation', '감금/Noun'),
#  ('감금/Noun', '만/Josa'),
#  ('만/Josa', '반복/Noun'),
#  ('반복/Noun', '반복/Noun'),
#  ('반복/Noun', '../Punctuation'),
#  ('../Punctuation', '이/Determiner'),
#  ('이/Determiner', '드라마/Noun'),
#  ('드라마/Noun', '는/Josa'),
#  ('는/Josa', '가족/Noun'),
#  ('가족/Noun', '도/Josa'),
#  ('도/Josa', '없다/Adjective'),
#  ('없다/Adjective', '연기/Noun'),
#  ('연기/Noun', '못/VerbPrefix'),
#  ('못/VerbPrefix', '하는/Verb'),
#  ('하는/Verb', '사람/Noun'),
#  ('사람/Noun', '만/Josa'),
#  ('만/Josa', '모/Modifier'),
#  ('모/Modifier', '엿/Modifier'),
#  ('엿/Modifier', '네/Noun'),
#  ('네/Noun', '</s>'),
#  ('<s>', '액션/Noun'),
#  ('액션/Noun', '이/Josa'),
#  ('이/Josa', '없는데도/Adjective'),
#  ('없는데도/Adjective', '재미/Noun'),
#  ('재미/Noun', '있는/Adjective'),
#  ('있는/Adjective', '몇/Noun'),
#  ('몇/Noun', '안되는/Adjective'),
#  ('안되는/Adjective', '영화/Noun'),
#  ('영화/Noun', '</s>'),
#  ('<s>', '왜케/Noun'),
#  ('왜케/Noun', '평점/Noun'),
#  ('평점/Noun', '이/Josa'),
#  ('이/Josa', '낮은건데/Adjective'),
#  ('낮은건데/Adjective', '?/Punctuation'),
#  ('?/Punctuation', '꽤/Noun'),
#  ('꽤/Noun', '볼/Noun'),
#  ('볼/Noun', '만/Josa'),
#  ('만/Josa', '한/Determiner'),
#  ('한/Determiner', '데/Noun'),
#  ('데/Noun', '../Punctuation'),
#  ('../Punctuation', '헐리우드/Noun'),
#  ('헐리우드/Noun', '식/Suffix'),
#  ('식/Suffix', '화려함에만/Adjective'),
#  ('화려함에만/Adjective', '너무/Adverb'),
#  ('너무/Adverb', '길들여져/Verb'),
#  ('길들여져/Verb', '있나/Adjective'),
#  ('있나/Adjective', '?/Punctuation'),
#  ('?/Punctuation', '</s>'),
#  ('<s>', '걍/Adverb'),
#  ('걍/Adverb', '인피니트/Noun'),
#  ('인피니트/Noun', '가/Josa'),
#  ('가/Josa', '짱/Noun'),
#  ('짱/Noun', '이다/Josa'),
#  ('이다/Josa', './Punctuation'),
#  ('./Punctuation', '진짜/Noun'),
#  ('진짜/Noun', '짱/Suffix'),
#  ('짱/Suffix', '이다/Josa'),
#  ('이다/Josa', '♥/Foreign'),
#  ('♥/Foreign', '</s>'),
#  ('<s>', '볼때/Noun'),
#  ('볼때/Noun', '마다/Josa'),
#  ('마다/Josa', '눈물나서/Verb'),
#  ('눈물나서/Verb', '죽겠다/Verb'),
#  ('죽겠다/Verb', '90년/Number'),
#  ('90년/Number', '대의/Foreign'),
#  ('대의/Foreign', '향수/Noun'),
#  ('향수/Noun', '자극/Noun'),
#  ('자극/Noun', '!!/Punctuation'),
#  ('!!/Punctuation', '허진호/Noun'),
#  ('허진호/Noun', '는/Josa'),
#  ('는/Josa', '감성/Noun'),
#  ('감성/Noun', '절제/Noun'),
#  ('절제/Noun', '멜로/Noun'),
#  ('멜로/Noun', '의/Josa'),
#  ('의/Josa', '달인/Noun'),
#  ('달인/Noun', '이다/Josa'),
#  ('이다/Josa', '~/Punctuation'),
#  ('~/Punctuation', '</s>'),
#  ('<s>', '울면/Noun'),
#  ('울면/Noun', '서/Josa'),
#  ('서/Josa', '손/Noun'),
#  ('손/Noun', '들/Suffix'),
#  ('들/Suffix', '고/Josa'),
#  ('고/Josa', '횡단보도/Noun'),
#  ('횡단보도/Noun', '건널/Verb'),
#  ('건널/Verb', '때/Noun'),
#  ('때/Noun', '뛰/Verb'),
#  ('뛰/Verb', '쳐나/Verb'),
#  ('쳐나/Verb', '올/Modifier'),
#  ('올/Modifier', '뻔/Noun'),
#  ('뻔/Noun', '이범수/Noun'),
#  ('이범수/Noun', '연기/Noun'),
#  ('연기/Noun', '드럽게/Adjective'),
#  ('드럽게/Adjective', '못/VerbPrefix'),
#  ('못/VerbPrefix', '해/Verb'),
#  ('해/Verb', '</s>'),
#  ('<s>', '담백하고/Adjective'),
#  ('담백하고/Adjective', '깔끔해서/Adjective'),
#  ('깔끔해서/Adjective', '좋다/Adjective'),
#  ('좋다/Adjective', './Punctuation'),
#  ('./Punctuation', '신/Modifier'),
#  ('신/Modifier', '문/Modifier'),
#  ('문/Modifier', '기/Modifier'),
#  ('기/Modifier', '사/Modifier'),
#  ('사/Modifier', '로만/Noun'),
#  ('로만/Noun', '보다/Verb'),
#  ('보다/Verb', '보면/Verb'),
#  ('보면/Verb', '자꾸/Noun'),
#  ('자꾸/Noun', '잊어버린다/Verb'),
#  ('잊어버린다/Verb', './Punctuation'),
#  ('./Punctuation', '그/Noun'),
#  ('그/Noun', '들/Suffix'),
#  ('들/Suffix', '도/Josa'),
#  ('도/Josa', '사람/Noun'),
#  ('사람/Noun', '이었다는/Verb'),
#  ('이었다는/Verb', '것/Noun'),
#  ('것/Noun', '을/Josa'),
#  ('을/Josa', './Punctuation'),
#  ('./Punctuation', '</s>'),
#  ('<s>', '취향/Noun'),
#  ('취향/Noun', '은/Josa'),
#  ('은/Josa', '존중/Noun'),
#  ('존중/Noun', '한/Determiner'),
#  ('한/Determiner', '다지/Noun'),
#  ('다지/Noun', '만/Josa'),
#  ('만/Josa', '진짜/Noun'),
#  ('진짜/Noun', '내생/Noun'),
#  ('내생/Noun', '에/Josa'),
#  ('에/Josa', '극장/Noun'),
#  ('극장/Noun', '에서/Josa'),
#  ('에서/Josa', '본/Verb'),
#  ('본/Verb', '영화/Noun'),
#  ('영화/Noun', '중/Suffix'),
#  ('중/Suffix', '가장/Noun'),
#  ('가장/Noun', '노잼/Noun'),
#  ('노잼/Noun', '노/Noun'),
#  ('노/Noun', '감동/Noun'),
#  ('감동/Noun', '임/Noun'),
#  ('임/Noun', '스토리/Noun'),
#  ('스토리/Noun', '도/Josa'),
#  ('도/Josa', '어거지/Noun'),
#  ('어거지/Noun', '고/Josa'),
#  ('고/Josa', '감동/Noun'),
#  ('감동/Noun', '도/Josa'),
#  ('도/Josa', '어거지/Noun'),
#  ('어거지/Noun', '</s>'),
#  ('<s>', 'ㄱ/KoreanParticle'),
#  ('ㄱ/KoreanParticle', '냥/Noun'),
#  ('냥/Noun', '매번/Noun'),
#  ('매번/Noun', '긴장/Noun'),
#  ('긴장/Noun', '되고/Verb'),
#  ('되고/Verb', '재밋음/Noun'),
#  ('재밋음/Noun', 'ㅠㅠ/KoreanParticle'),
#  ('ㅠㅠ/KoreanParticle', '</s>'),
#  ('<s>', '참/Verb'),
#  ('참/Verb', '사람/Noun'),
#  ('사람/Noun', '들/Suffix'),
#  ('들/Suffix', '웃긴게/Verb'),
#  ('웃긴게/Verb', '바스코/Noun'),
#  ('바스코/Noun', '가/Josa'),
#  ('가/Josa', '이기/Noun'),
#  ('이기/Noun', '면/Josa'),
#  ('면/Josa', '락스/Noun'),
#  ('락스/Noun', '코/Noun'),
#  ('코/Noun', '라고/Josa'),
#  ('라고/Josa', '까고/Verb'),
#  ('까고/Verb', '바비/Noun'),
#  ('바비/Noun', '가/Josa'),
#  ('가/Josa', '이기/Noun'),
#  ('이기/Noun', '면/Josa'),
#  ('면/Josa', '아이돌/Noun'),
#  ('아이돌/Noun', '이라고/Josa'),
#  ('이라고/Josa', '깐다/Verb'),
#  ('깐다/Verb', './Punctuation'),
#  ('./Punctuation', '그냥/Noun'),
#  ('그냥/Noun', '까고싶어서/Verb'),
#  ('까고싶어서/Verb', '안달/Noun'),
#  ('안달/Noun', '난/Josa'),
#  ('난/Josa', '것/Noun'),
#  ('것/Noun', '처럼/Josa'),
#  ('처럼/Josa', '보인다/Verb'),
#  ('보인다/Verb', '</s>'),
#  ('<s>', '굿바이/Noun'),
#  ('굿바이/Noun', '레닌/Noun'),
#  ('레닌/Noun', '표절/Noun'),
#  ('표절/Noun', '인/Josa'),
#  ('인/Josa', '것/Noun'),
#  ('것/Noun', '은/Josa'),
#  ('은/Josa', '이해/Noun'),
#  ('이해/Noun', '하는데/Verb'),
#  ('하는데/Verb', '왜/Noun'),
#  ('왜/Noun', '뒤/Noun'),
#  ('뒤/Noun', '로/Josa'),
#  ('로/Josa', '갈수록/Noun'),
#  ('갈수록/Noun', '재미/Noun'),
#  ('재미/Noun', '없어지냐/Verb'),
#  ('없어지냐/Verb', '</s>'),
#  ('<s>', '이건/Noun'),
#  ('이건/Noun', '정말/Noun'),
#  ('정말/Noun', '깨알/Noun'),
#  ('깨알/Noun', '캐스팅/Noun'),
#  ('캐스팅/Noun', '과/Josa'),
#  ('과/Josa', '질퍽/Noun'),
#  ('질퍽/Noun', '하/Suffix'),
#  ('하/Suffix', '지/Josa'),
#  ('지/Josa', '않은/Verb'),
#  ('않은/Verb', '산뜻한/Adjective'),
#  ('산뜻한/Adjective', '내/Determiner'),
#  ('내/Determiner', '용구성/Noun'),
#  ('용구성/Noun', '이/Josa'),
#  ('이/Josa', '잘/Verb'),
#  ('잘/Verb', '버무러진/Noun'),
#  ('버무러진/Noun', '깨알/Noun'),
#  ('깨알/Noun', '일드/Noun'),
#  ('일드/Noun', '!!/Punctuation'),
#  ('!!/Punctuation', '♥/Foreign'),
#  ('♥/Foreign', '</s>'),
#  ('<s>', '약탈/Noun'),
#  ('약탈/Noun', '자/Suffix'),
#  ('자/Suffix', '를/Josa'),
#  ('를/Josa', '위/Noun'),
#  ('위/Noun', '한/Josa'),
#  ('한/Josa', '변명/Noun'),
#  ('변명/Noun', ',/Punctuation'),
#  (',/Punctuation', '이라/Verb'),
#  ('이라/Verb', './Punctuation'),
#  ('./Punctuation', '저/Determiner'),
#  ('저/Determiner', '놈/Noun'),
#  ('놈/Noun', '들/Suffix'),
#  ('들/Suffix', '은/Josa'),
#  ('은/Josa', '착한/Adjective'),
#  ('착한/Adjective', '놈/Noun'),
#  ('놈/Noun', '들/Suffix'),
#  ('들/Suffix', '절대/Noun'),
#  ('절대/Noun', '아닌/Adjective'),
#  ('아닌/Adjective', '걸/Noun'),
#  ('걸/Noun', '요/Josa'),
#  ('요/Josa', './Punctuation'),
#  ('./Punctuation', '</s>'),
#  ('<s>', '나름/Noun'),
#  ('나름/Noun', '심오한/Adjective'),
#  ('심오한/Adjective', '뜻/Noun'),
#  ('뜻/Noun', '도/Josa'),
#  ('도/Josa', '있는/Adjective'),
#  ('있는/Adjective', '듯/Noun'),
#  ('듯/Noun', './Punctuation'),
#  ('./Punctuation', '그냥/Noun'),
#  ('그냥/Noun', '학생/Noun'),
#  ('학생/Noun', '이/Josa'),
#  ('이/Josa', '선생/Noun'),
#  ('선생/Noun', '과/Josa'),
#  ('과/Josa', '놀아나는/Verb'),
#  ('놀아나는/Verb', '영화/Noun'),
#  ('영화/Noun', '는/Josa'),
#  ('는/Josa', '절대/Noun'),
#  ('절대/Noun', '아님/Adjective'),
#  ('아님/Adjective', '</s>'),
#  ('<s>', '보면서/Verb'),
#  ('보면서/Verb', '웃지/Verb'),
#  ('웃지/Verb', '않는/Verb'),
#  ('않는/Verb', '건/Noun'),
#  ('건/Noun', '불가능하다/Adjective'),
#  ('불가능하다/Adjective', '</s>'),
#  ('<s>', '재미없다/Adjective'),
#  ('재미없다/Adjective', '지루하고/Adjective'),
#  ('지루하고/Adjective', './Punctuation'),
#  ('./Punctuation', '같은/Adjective'),
#  ('같은/Adjective', '음식/Noun'),
#  ('음식/Noun', '영화/Noun'),
#  ('영화/Noun', '인데/Josa'),
#  ('인데/Josa', '도/Noun'),
#  ('도/Noun', '바베트/Noun'),
#  ('바베트/Noun', '의/Josa'),
#  ('의/Josa', '만찬/Noun'),
#  ('만찬/Noun', '하고/Josa'),
#  ('하고/Josa', '넘/Verb'),
#  ('넘/Verb', '차이남/Verb'),
#  ('차이남/Verb', '..../Punctuation'),
#  ('..../Punctuation', '바베트/Noun'),
#  ('바베트/Noun', '의/Josa'),
#  ('의/Josa', '만찬/Noun'),
#  ('만찬/Noun', '은/Josa'),
#  ('은/Josa', '이야기/Noun'),
#  ('이야기/Noun', '도/Josa'),
#  ('도/Josa', '있고/Adjective'),
#  ('있고/Adjective', '음식/Noun'),
#  ('음식/Noun', '보는/Verb'),
#  ('보는/Verb', '재미/Noun'),
#  ('재미/Noun', '도/Josa'),
#  ('도/Josa', '있는데/Adjective'),
#  ('있는데/Adjective', ';/Punctuation'),
#  (';/Punctuation', '이건/Noun'),
#  ('이건/Noun', '볼/Noun'),
#  ('볼/Noun', '게/Josa'),
#  ('게/Josa', '없다/Adjective'),
#  ('없다/Adjective', '음식/Noun'),
#  ('음식/Noun', '도/Josa'),
#  ('도/Josa', '별로/Noun'),
#  ('별로/Noun', '안/VerbPrefix'),
#  ('안/VerbPrefix', '나오고/Verb'),
#  ('나오고/Verb', ',/Punctuation'),
#  (',/Punctuation', '핀란드/Noun'),
#  ('핀란드/Noun', '풍경/Noun'),
#  ('풍경/Noun', '이라도/Josa'),
#  ('이라도/Josa', '구/Modifier'),
#  ('구/Modifier', '경/Modifier'),
#  ('경/Modifier', '할랫/Noun'),
#  ('할랫/Noun', '는데/Verb'),
#  ('는데/Verb', '그것/Noun'),
#  ('그것/Noun', '도/Josa'),
#  ('도/Josa', '별로/Noun'),
#  ('별로/Noun', '안/VerbPrefix'),
#  ('안/VerbPrefix', '나옴/Verb'),
#  ('나옴/Verb', 'ㅡㅡ/KoreanParticle'),
#  ('ㅡㅡ/KoreanParticle', '</s>'),
#  ('<s>', '절대/Noun'),
#  ('절대/Noun', '평범한/Adjective'),
#  ('평범한/Adjective', '영화/Noun'),
#  ('영화/Noun', '가/Josa'),
#  ('가/Josa', '아닌/Adjective'),
#  ('아닌/Adjective', '수작/Noun'),
#  ('수작/Noun', '이라/Josa'),
#  ('이라/Josa', '는걸/Noun'),
#  ('는걸/Noun', '말씀드립니다/Verb'),
#  ('말씀드립니다/Verb', './Punctuation'),
#  ('./Punctuation', '</s>'),
#  ('<s>', '주제/Noun'),
#  ('주제/Noun', '는/Josa'),
#  ('는/Josa', '좋은데/Adjective'),
#  ('좋은데/Adjective', '중반/Noun'),
#  ('중반/Noun', '부터/Josa'),
#  ('부터/Josa', '지루하다/Adjective'),
#  ('지루하다/Adjective', '</s>'),
#  ('<s>', '다/Adverb'),
#  ('다/Adverb', '짤랐을꺼/Noun'),
#  ('짤랐을꺼/Noun', '야/Josa'),
#  ('야/Josa', './Punctuation'),
#  ('./Punctuation', '그래서/Adverb'),
#  ('그래서/Adverb', '납득/Noun'),
#  ('납득/Noun', '할/Verb'),
#  ('할/Verb', '수/Noun'),
#  ('수/Noun', '없었던거야/Adjective'),
#  ('없었던거야/Adjective', '../Punctuation'),
#  ('../Punctuation', '그럴꺼야/Adjective'),
#  ('그럴꺼야/Adjective', '../Punctuation'),
#  ('../Punctuation', '꼭/Noun'),
#  ('꼭/Noun', '그랬던걸/Adjective'),
#  ('그랬던걸/Adjective', '꺼야/Verb'),
#  ('꺼야/Verb', '../Punctuation'),
#  ('../Punctuation', '</s>'),
#  ('<s>', 'kl/Alpha'),
#  ('kl/Alpha', '2/Number'),
#  ('2/Number', 'g/Alpha'),
#  ('g/Alpha', '고추/Noun'),
#  ('고추/Noun', '를/Josa'),
#  ('를/Josa', '털어/Verb'),
#  ('털어/Verb', '버려야/Verb'),
#  ('버려야/Verb', '할텐데/Verb'),
#  ('할텐데/Verb', '</s>'),
#  ('<s>', '카밀라/Noun'),
#  ('카밀라/Noun', '벨/Noun'),
#  ('벨/Noun', '발연기/Noun'),
#  ('발연기/Noun', '</s>'),
#  ('<s>', '재밋는뎅/Noun'),
#  ('재밋는뎅/Noun', '</s>'),
#  ('<s>', '센스/Noun'),
#  ('센스/Noun', '있는/Adjective'),
#  ('있는/Adjective', '연출/Noun'),
#  ('연출/Noun', '력/Suffix'),
#  ('력/Suffix', '../Punctuation'),
#  ('../Punctuation', '탁월한/Adjective'),
#  ('탁월한/Adjective', '캐스팅/Noun'),
#  ('캐스팅/Noun', '../Punctuation'),
#  ('../Punctuation', '90년/Number'),
#  ('90년/Number', '대의/Foreign'),
#  ('대의/Foreign', '향수/Noun'),
#  ('향수/Noun', '../Punctuation'),
#  ('../Punctuation', '그래서/Adverb'),
#  ('그래서/Adverb', '9/Number'),
#  ('9/Number', '점/Noun'),
#  ('점/Noun', '../Punctuation'),
#  ('../Punctuation', '</s>'),
#  ('<s>', '엄포스/Noun'),
#  ('엄포스/Noun', '의/Josa'),
#  ('의/Josa', '위력/Noun'),
#  ('위력/Noun', '을/Josa'),
#  ('을/Josa', '다시/Noun'),
#  ('다시/Noun', '한번/Noun'),
#  ('한번/Noun', '깨닫게/Verb'),
#  ('깨닫게/Verb', '해준/Verb'),
#  ('해준/Verb', '적/Noun'),
#  ('적/Noun', './Punctuation'),
#  ('./Punctuation', '남/Noun'),
#  ('남/Noun', '꽃/Noun'),
#  ('꽃/Noun', '검사/Noun'),
#  ('검사/Noun', '님/Suffix'),
#  ('님/Suffix', '도/Josa'),
#  ('도/Josa', '연기/Noun'),
#  ('연기/Noun', '정말/Noun'),
#  ('정말/Noun', '좋았어요/Adjective'),
#  ('좋았어요/Adjective', '!/Punctuation'),
#  ('!/Punctuation', '완전/Noun'),
#  ('완전/Noun', '명품/Noun'),
#  ('명품/Noun', '드라마/Noun'),
#  ('드라마/Noun', '!/Punctuation'),
#  ('!/Punctuation', '</s>'),
#  ('<s>', '졸/Noun'),
#  ('졸/Noun', '쓰레기/Noun'),
#  ('쓰레기/Noun', '진부하고말/Adjective'),
#  ('진부하고말/Adjective', '도안/Noun'),
#  ('도안/Noun', '됌/Verb'),
#  ('됌/Verb', 'ㅋㅋ/KoreanParticle'),
#  ('ㅋㅋ/KoreanParticle', '아/Exclamation'),
#  ('아/Exclamation', '../Punctuation'),
#  ('../Punctuation', '시간/Noun'),
#  ('시간/Noun', '아까워/Adjective'),
#  ('아까워/Adjective', '</s>'),
#  ('<s>', '재밌는데/Adjective'),
#  ('재밌는데/Adjective', '별/Modifier'),
#  ('별/Modifier', '점/Noun'),
#  ('점/Noun', '이/Josa'),
#  ('이/Josa', '왜/Noun'),
#  ('왜/Noun', '이리/Adverb'),
#  ('이리/Adverb', '낮은고/Adjective'),
#  ('낮은고/Adjective', '</s>'),
#  ('<s>', '1%/Number'),
#  ('1%/Number', '라도/Josa'),
#  ('라도/Josa', '기대했던/Adjective'),
#  ('기대했던/Adjective', '내/Noun'),
#  ('내/Noun', '가/Josa'),
#  ('가/Josa', '죄인/Noun'),
#  ('죄인/Noun', '입니다/Adjective'),
#  ('입니다/Adjective', '죄인/Noun'),
#  ('죄인/Noun', '입니다/Adjective'),
#  ('입니다/Adjective', '..../Punctuation'),
#  ('..../Punctuation', '</s>'),
#  ('<s>', '아직도/Adverb'),
#  ('아직도/Adverb', '이/Noun'),
#  ('이/Noun', '드라마/Noun'),
#  ('드라마/Noun', '는/Josa'),
#  ('는/Josa', '내/Determiner'),
#  ('내/Determiner', '인생/Noun'),
#  ('인생/Noun', '의/Josa'),
#  ('의/Josa', '최고/Noun'),
#  ('최고/Noun', '!/Punctuation'),
#  ('!/Punctuation', '</s>'),
#  ('<s>', '패션/Noun'),
#  ('패션/Noun', '에/Josa'),
#  ('에/Josa', '대한/Noun'),
#  ('대한/Noun', '열정/Noun'),
#  ('열정/Noun', '!/Punctuation'),
#  ('!/Punctuation', '안나/Noun'),
#  ('안나/Noun', '윈/Noun'),
#  ('윈/Noun', '투어/Noun'),
#  ('투어/Noun', '!/Punctuation'),
#  ('!/Punctuation', '</s>'),
#  ('<s>', '키이라/Noun'),
#  ('키이라/Noun', '나이틀리/Noun'),
#  ('나이틀리/Noun', '가/Josa'),
#  ('가/Josa', '연기/Noun'),
#  ('연기/Noun', '하고자/Verb'),
#  ('하고자/Verb', '했던건/Verb'),
#  ('했던건/Verb', '대체/Noun'),
#  ('대체/Noun', '정신장애/Noun'),
#  ('정신장애/Noun', '일까/Verb'),
#  ('일까/Verb', '틱장애/Noun'),
#  ('틱장애/Noun', '일까/Verb'),
#  ('일까/Verb', '</s>'),
#  ('<s>', '허허/Adverb'),
#  ('허허/Adverb', '.../Punctuation'),
#  ('.../Punctuation', '원작/Noun'),
#  ('원작/Noun', '가/Josa'),
#  ('가/Josa', '정신/Noun'),
#  ('정신/Noun', '나간/Verb'),
#  ('나간/Verb', '유령/Noun'),
#  ('유령/Noun', '이라/Josa'),
#  ('이라/Josa', '.../Punctuation'),
#  ('.../Punctuation', '재미있겠네요/Adjective'),
#  ('재미있겠네요/Adjective', '!/Punctuation'),
#  ('!/Punctuation', '</s>'),
#  ('<s>', '포스터/Noun'),
#  ('포스터/Noun', '는/Josa'),
#  ('는/Josa', '있어/Adjective'),
#  ('있어/Adjective', '보이는데/Verb'),
#  ('보이는데/Verb', '관객/Noun'),
#  ('관객/Noun', '은/Josa'),
#  ('은/Josa', '114/Number'),
#  ('114/Number', '명/Noun'),
#  ('명/Noun', '이네/Josa'),
#  ('이네/Josa', '</s>'),
#  ('<s>', '이/Noun'),
#  ('이/Noun', '영화/Noun'),
#  ('영화/Noun', '가/Josa'),
#  ('가/Josa', '왜/Noun'),
#  ('왜/Noun', '이렇게/Adverb'),
#  ('이렇게/Adverb', '저/Determiner'),
#  ('저/Determiner', '평가/Noun'),
#  ('평가/Noun', '받는지/Verb'),
#  ('받는지/Verb', '모르겠다/Verb'),
#  ('모르겠다/Verb', '</s>'),
#  ('<s>', '단순하면서/Adjective'),
#  ('단순하면서/Adjective', '은은한/Adjective'),
#  ('은은한/Adjective', '매력/Noun'),
#  ('매력/Noun', '의/Josa'),
#  ('의/Josa', '영화/Noun'),
#  ('영화/Noun', '</s>'),
#  ('<s>', "'/Punctuation"),
#  ("'/Punctuation", '다/Adverb'),
#  ('다/Adverb', '알바생/Noun'),
#  ('알바생/Noun', '인가/Josa'),
#  ('인가/Josa', '내용/Noun'),
#  ('내용/Noun', '도/Josa'),
#  ('도/Josa', '없고/Adjective'),
#  ('없고/Adjective', '무서운거도/Adjective'),
#  ('무서운거도/Adjective', '없고/Adjective'),
#  ('없고/Adjective', '웃긴거도/Verb'),
#  ('웃긴거도/Verb', '하나/Noun'),
#  ('하나/Noun', '도/Josa'),
#  ('도/Josa', '없음/Adjective'),
#  ('없음/Adjective', '완전/Noun'),
#  ('완전/Noun', '별/Noun'),
#  ('별/Noun', '싱거운/Adjective'),
#  ('싱거운/Adjective', '영화/Noun'),
#  ('영화/Noun', './Punctuation'),
#  ('./Punctuation', 'ㅇ/KoreanParticle'),
#  ('ㅇ/KoreanParticle', './Punctuation'),
#  ('./Punctuation', 'ㅇ/KoreanParticle'),
#  ('ㅇ/KoreanParticle', '내/Noun'),
#  ('내/Noun', 'ㅇ/KoreanParticle'),
#  ('ㅇ/KoreanParticle', '시간/Noun'),
#  ('시간/Noun', '넘/Verb'),
#  ('넘/Verb', '아까/Adjective'),
#  ('아까/Adjective', '움/Noun'),
#  ('움/Noun', '../Punctuation'),
#  ('../Punctuation', './Punctuation'),
#  ('./Punctuation', '완전/Noun'),
#  ('완전/Noun', '낚임/Noun'),
#  ('낚임/Noun', '</s>'),
#  ('<s>', '오게/Verb'),
#  ('오게/Verb', '두어라/Verb'),
#  ('두어라/Verb', '!/Punctuation'),
#  ('!/Punctuation', '서리/Noun'),
#  ('서리/Noun', '한/Determiner'),
#  ('한/Determiner', '이/Noun'),
#  ('이/Noun', '굶주렸다/Verb'),
#  ('굶주렸다/Verb', '!/Punctuation'),
#  ('!/Punctuation', '</s>'),
#  ('<s>', '정말/Noun'),
#  ('정말/Noun', '맘/Noun'),
#  ('맘/Noun', '에/Josa'),
#  ('에/Josa', '들어요/Verb'),
#  ('들어요/Verb', './Punctuation'),
#  ('./Punctuation', '그래서/Adverb'),
#  ('그래서/Adverb', '또/Noun'),
#  ('또/Noun', '보고싶은데/Verb'),
#  ('보고싶은데/Verb', '또/Noun'),
#  ('또/Noun', '보는/Verb'),
#  ('보는/Verb', '방법/Noun'),
#  ('방법/Noun', '이/Josa'),
#  ('이/Josa', '없네/Adjective'),
#  ('없네/Adjective', '?/Punctuation'),
#  ('?/Punctuation', '>../Punctuation'),
#  ('>../Punctuation', 'ㅜㅡ/KoreanParticle'),
#  ('ㅜㅡ/KoreanParticle', '</s>'),
#  ('<s>', '윤제문/Noun'),
#  ('윤제문/Noun', '이라는/Josa'),
#  ('이라는/Josa', '멋진/Adjective'),
#  ('멋진/Adjective', '배우/Noun'),
#  ('배우/Noun', '를/Josa'),
#  ('를/Josa', '발견/Noun'),
#  ('발견/Noun', '하게/Verb'),
#  ('하게/Verb', '됐어요/Verb'),
#  ('됐어요/Verb', './Punctuation'),
#  ('./Punctuation', '소소한/Adjective'),
#  ('소소한/Adjective', '일/Modifier'),
#  ('일/Modifier', '탈/Noun'),
#  ('탈/Noun', '이/Josa'),
#  ('이/Josa', '잔잔한/Adjective'),
#  ('잔잔한/Adjective', '미소/Noun'),
#  ('미소/Noun', '를/Josa'),
#  ('를/Josa', '머금/Noun'),
#  ('머금/Noun', '게/Josa'),
#  ('게/Josa', '합니다/Verb'),
#  ('합니다/Verb', './Punctuation'),
#  ('./Punctuation', '음악/Noun'),
#  ('음악/Noun', '은/Josa'),
#  ('은/Josa', '조금/Noun'),
#  ('조금/Noun', '아쉽네요/Adjective'),
#  ('아쉽네요/Adjective', 'ㅠㅠ/KoreanParticle'),
#  ('ㅠㅠ/KoreanParticle', '8/Number'),
#  ('8/Number', '점/Noun'),
#  ('점/Noun', '주고/Verb'),
#  ('주고/Verb', '싶은데/Verb'),
#  ('싶은데/Verb', '평점/Noun'),
#  ('평점/Noun', '올리고/Verb'),
#  ('올리고/Verb', '싶어/Verb'),
#  ('싶어/Verb', '10/Number'),
#  ('10/Number', '점/Noun'),
#  ('점/Noun', '줄게요/Verb'),
#  ('줄게요/Verb', '^^/Punctuation'),
#  ('^^/Punctuation', '</s>'),
#  ('<s>', '평점/Noun'),
#  ('평점/Noun', '에/Josa'),
#  ('에/Josa', '속지/Noun'),
#  ('속지/Noun', '마시길/Verb'),
#  ('마시길/Verb', '시간/Noun'),
#  ('시간/Noun', '낭비/Noun'),
#  ('낭비/Noun', '돈/Noun'),
#  ('돈/Noun', '낭비/Noun'),
#  ('낭비/Noun', '임/Noun'),
#  ('임/Noun', '</s>'),
#  ('<s>', '리얼리티/Noun'),
#  ('리얼리티/Noun', '가/Josa'),
#  ('가/Josa', '뛰어나긴/Adjective'),
#  ('뛰어나긴/Adjective', '한데/Eomi'),
#  ('한데/Eomi', '큰/Verb'),
#  ('큰/Verb', '공감/Noun'),
#  ('공감/Noun', '은/Josa'),
#  ('은/Josa', '안/Noun'),
#  ('안/Noun', '간다/Noun'),
#  ('간다/Noun', './Punctuation'),
#  ('./Punctuation', '이민기/Noun'),
#  ('이민기/Noun', '캐릭터/Noun'),
#  ('캐릭터/Noun', '는/Josa'),
#  ('는/Josa', '정신의학/Noun'),
#  ('정신의학/Noun', '상/Suffix'),
#  ('상/Suffix', '분노조절/Noun'),
#  ('분노조절/Noun', '장애/Noun'),
#  ('장애/Noun', '초기/Noun'),
#  ('초기/Noun', '증상/Noun'),
#  ('증상/Noun', '일거다/Verb'),
#  ('일거다/Verb', './Punctuation'),
#  ('./Punctuation', '툭하면/Noun'),
#  ('툭하면/Noun', '사람/Noun'),
#  ('사람/Noun', '패/Noun'),
#  ('패/Noun', '고/Josa'),
#  ('고/Josa', '욕/Noun'),
#  ('욕/Noun', '하고/Josa'),
#  ('하고/Josa', '물건/Noun'),
#  ('물건/Noun', '파손/Noun'),
#  ('파손/Noun', '하고/Josa'),
#  ('하고/Josa', '../Punctuation'),
#  ('../Punctuation', '조금/Noun'),
#  ('조금/Noun', '오/Modifier'),
#  ('오/Modifier', '바/Noun'),
#  ('바/Noun', '였음/Verb'),
#  ('였음/Verb', './Punctuation'),
#  ('./Punctuation', '극/Modifier'),
#  ('극/Modifier', '초반/Noun'),
#  ('초반/Noun', '엔/Josa'),
#  ('엔/Josa', '신선했는데/Adjective'),
#  ('신선했는데/Adjective', '가면/Noun'),
#  ('가면/Noun', '갈수록/Noun'),
#  ('갈수록/Noun', '이민기/Noun'),
#  ('이민기/Noun', '정신/Noun'),
#  ('정신/Noun', '상태/Noun'),
#  ('상태/Noun', '공감/Noun'),
#  ('공감/Noun', '불가/Noun'),
#  ('불가/Noun', './Punctuation'),
#  ('./Punctuation', '</s>'),
#  ('<s>', '마이너스/Noun'),
#  ('마이너스/Noun', '는/Josa'),
#  ('는/Josa', '왜/Noun'),
#  ('왜/Noun', '없냐/Adjective'),
#  ('없냐/Adjective', 'ㅋ/KoreanParticle'),
#  ('ㅋ/KoreanParticle', '뮤비/Noun'),
#  ('뮤비/Noun', '보고/Noun'),
#  ('보고/Noun', '영화/Noun'),
#  ('영화/Noun', '수준/Noun'),
#  ('수준/Noun', '딱/Adverb'),
#  ('딱/Adverb', '알/Noun'),
#  ('알/Noun', '만/Josa'),
#  ('만/Josa', '하더군/Verb'),
#  ('하더군/Verb', 'ㅉㅉ/KoreanParticle'),
#  ('ㅉㅉ/KoreanParticle', '북한/Noun'),
#  ('북한/Noun', '에서/Josa'),
#  ('에서/Josa', '이런거/Adjective'),
#  ('이런거/Adjective', '만들라고/Verb'),
#  ('만들라고/Verb', '돈/Noun'),
#  ('돈/Noun', '대주던/Verb'),
#  ('대주던/Verb', '?/Punctuation'),
#  ('?/Punctuation', '</s>'),
#  ('<s>', '난/Noun'),
#  ('난/Noun', '우리/Noun'),
#  ('우리/Noun', '영화/Noun'),
#  ('영화/Noun', '를/Josa'),
#  ('를/Josa', '사랑/Noun'),
#  ('사랑/Noun', '합니다/Verb'),
#  ('합니다/Verb', '....^^;/Punctuation'),
#  ('....^^;/Punctuation', '</s>'),
#  ('<s>', '데/Noun'),
#  ('데/Noun', '너/Modifier'),
#  ('너/Modifier', '리스/Noun'),
#  ('리스/Noun', '타르/Noun'),
#  ('타르/Noun', '가르엔/Verb'),
#  ('가르엔/Verb', '.../Punctuation'),
#  ('.../Punctuation', '나도/Verb'),
#  ('나도/Verb', '용의/Noun'),
#  ('용의/Noun', '주인/Noun'),
#  ('주인/Noun', '이/Josa'),
#  ('이/Josa', '되고/Verb'),
#  ('되고/Verb', '싶다/Verb'),
#  ('싶다/Verb', '.../Punctuation'),
#  ('.../Punctuation', '누/Noun'),
#  ('누/Noun', '이랑/Josa'),
#  ('이랑/Josa', ',/Punctuation'),
#  (',/Punctuation', '근친상간/Noun'),
#  ('근친상간/Noun', '이나/Josa'),
#  ('이나/Josa', '하고/Verb'),
#  ('하고/Verb', '다닐지라도/Verb'),
#  ('다닐지라도/Verb', ',/Punctuation'),
#  (',/Punctuation', '소설/Noun'),
#  ('소설/Noun', '속/Noun'),
#  ('속/Noun', '에선/Josa'),
#  ('에선/Josa', '제일/Noun'),
#  ('제일/Noun', '멋진/Adjective'),
#  ('멋진/Adjective', '놈/Noun'),
#  ('놈/Noun', '이/Josa'),
#  ('이/Josa', '자/Noun'),
#  ('자/Noun', '이/Determiner'),
#  ('이/Determiner', '메/Noun'),
#  ('메/Noun', '라/Josa'),
#  ('라/Josa', '니스/Noun'),
#  ('니스/Noun', '터/Noun'),
#  ('터/Noun', '였는데/Verb'),
#  ('였는데/Verb', ',/Punctuation'),
#  (',/Punctuation', '드라마/Noun'),
#  ('드라마/Noun', '속/Noun'),
#  ('속/Noun', '에선/Josa'),
#  ('에선/Josa', ',/Punctuation'),
#  (',/Punctuation', '드래곤/Noun'),
#  ('드래곤/Noun', '(/Punctuation'),
#  ('(/Punctuation', '용/Noun'),
#  ('용/Noun', ')/Punctuation'),
#  (')/Punctuation', '이/Noun'),
#  ('이/Noun', '제일/Noun'),
#  ('제일/Noun', '멋지네/Adjective'),
#  ('멋지네/Adjective', '(/Punctuation'),
#  ('(/Punctuation', '웃음/Noun'),
#  ('웃음/Noun', ')/Punctuation'),
#  (')/Punctuation', '감독/Noun'),
#  ('감독/Noun', '님/Suffix'),
#  ('님/Suffix', '토르/Noun'),
#  ('토르/Noun', '-/Punctuation'),
#  ('-/Punctuation', '2/Number'),
#  ('2/Number', '다크/Noun'),
#  ('다크/Noun', '월드/Noun'),
#  ('월드/Noun', '는/Josa'),
#  ('는/Josa', '말/Noun'),
#  ('말/Noun', '아/Josa'),
#  ('아/Josa', '잡수셨을지라도/Verb'),
#  ('잡수셨을지라도/Verb', ',/Punctuation'),
#  (',/Punctuation', '기본/Noun'),
#  ('기본/Noun', '선방/Noun'),
#  ('선방/Noun', '은/Josa'),
#  ('은/Josa', '했음/Verb'),
#  ('했음/Verb', '</s>'),
#  ('<s>', '영화/Noun'),
#  ('영화/Noun', '가/Josa'),
#  ('가/Josa', '사람/Noun'),
#  ('사람/Noun', '의/Josa'),
#  ('의/Josa', '영혼/Noun'),
#  ('영혼/Noun', '을/Josa'),
#  ('을/Josa', '어루만져/Verb'),
#  ('어루만져/Verb', '줄/Noun'),
#  ('줄/Noun', '수도/Noun'),
#  ('수도/Noun', '있군요/Adjective'),
#  ('있군요/Adjective', '거친/Verb'),
#  ('거친/Verb', '세/Modifier'),
#  ('세/Modifier', '상사/Noun'),
#  ('상사/Noun', '를/Josa'),
#  ('를/Josa', '잠시/Noun'),
#  ('잠시/Noun', '잊고/Verb'),
#  ('잊고/Verb', '동화/Noun'),
#  ('동화/Noun', '같은/Adjective'),
#  ('같은/Adjective', '영화/Noun'),
#  ('영화/Noun', '에/Josa'),
#  ('에/Josa', '행복했네요/Adjective'),
#  ('행복했네요/Adjective', '</s>'),
#  ('<s>', '야/Exclamation'),
#  ('야/Exclamation', '세르게이/Noun'),
#  ('세르게이/Noun', '!/Punctuation'),
#  ('!/Punctuation', '작은/Adjective'),
#  ('작은/Adjective', '고추/Noun'),
#  ('고추/Noun', '의/Josa'),
#  ('의/Josa', '매운/Adjective'),
#  ('매운/Adjective', '맛/Noun'),
#  ('맛/Noun', '을/Josa'),
#  ('을/Josa', '보여주마/Verb'),
#  ('보여주마/Verb', '!/Punctuation'),
#  ('!/Punctuation', '포퐁/Noun'),
#  ('포퐁/Noun', '저그/Noun'),
#  ('저그/Noun', '콩/Noun'),
#  ('콩/Noun', '진호/Noun'),
#  ('진호/Noun', '가/Josa'),
#  ('가/Josa', '간다/Noun'),
#  ('간다/Noun', '</s>'),
#  ('<s>', '이렇게/Adverb'),
#  ('이렇게/Adverb', '가슴/Noun'),
#  ('가슴/Noun', '시리/Noun'),
#  ('시리/Noun', '게/Josa'),
#  ('게/Josa', '본/Verb'),
#  ('본/Verb', '드라마/Noun'),
#  ('드라마/Noun', '가/Josa'),
#  ('가/Josa', '또/Noun'),
#  ('또/Noun', '있을까/Adjective'),
#  ('있을까/Adjective', '?/Punctuation'),
#  ('?/Punctuation', '감동/Noun'),
#  ('감동/Noun', '그/Noun'),
#  ('그/Noun', '자체/Noun'),
#  ('자체/Noun', '!/Punctuation'),
#  ('!/Punctuation', '</s>'),
#  ('<s>', '난또/Noun'),
#  ('난또/Noun', '저/Noun'),
#  ('저/Noun', '꼬마/Noun'),
#  ('꼬마/Noun', '애가/Noun'),
#  ('애가/Noun', '무슨/Noun'),
#  ('무슨/Noun', '원한/Noun'),
#  ('원한/Noun', '이/Josa'),
#  ('이/Josa', '깊길래/Adjective'),
#  ('깊길래/Adjective', '.,./Punctuation'),
#  ('.,./Punctuation', '했더니/Verb'),
#  ('했더니/Verb', 'OO/Alpha'),
#  ('OO/Alpha', '그냥/Noun'),
#  ('그냥/Noun', '혼자/Noun'),
#  ('혼자/Noun', '나대다/Verb'),
#  ('나대다/Verb', 'OO/Alpha'),
#  ('OO/Alpha', '걸/Noun'),
#  ('걸/Noun', '어쩌라고/Adverb'),
#  ('어쩌라고/Adverb', './Punctuation'),
#  ('./Punctuation', '</s>'),
#  ('<s>', '재미있어요/Adjective'),
#  ('재미있어요/Adjective', '</s>'),
#  ('<s>', '전/Noun'),
#  ('전/Noun', '좋아요/Adjective'),
#  ('좋아요/Adjective', '</s>'),
#  ('<s>', '최고/Noun'),
#  ('최고/Noun', '</s>'),
#  ('<s>', '너무/Adverb'),
#  ('너무/Adverb', '충격/Noun'),
#  ('충격/Noun', '적이엇다/Verb'),
#  ('적이엇다/Verb', './Punctuation'),
#  ('./Punctuation', '기분/Noun'),
#  ('기분/Noun', '을/Josa'),
#  ('을/Josa', '완전히/Adjective'),
#  ('완전히/Adjective', '푹/Noun'),
#  ('푹/Noun', '꺼지게/Verb'),
#  ('꺼지게/Verb', '하는/Verb'),
#  ('하는/Verb', '느낌/Noun'),
#  ('느낌/Noun', '.../Punctuation'),
#  ('.../Punctuation', '활/Noun'),
#  ('활/Noun', '력/Suffix'),
#  ('력/Suffix', '이라고는/Josa'),
#  ('이라고는/Josa', '하나/Noun'),
#  ('하나/Noun', '도/Josa'),
#  ('도/Josa', '없는/Adjective'),
#  ('없는/Adjective', '너무나도/Adverb'),
#  ('너무나도/Adverb', '무거운/Adjective'),
#  ('무거운/Adjective', '..../Punctuation'),
#  ('..../Punctuation', '지독하고/Adjective'),
#  ('지독하고/Adjective', '차갑고/Adjective'),
#  ('차갑고/Adjective', '무자비하다/Adjective'),
#  ('무자비하다/Adjective', './Punctuation'),
#  ('./Punctuation', '그저/Adverb'),
#  ('그저/Adverb', '일본인/Noun'),
#  ('일본인/Noun', '들/Suffix'),
#  ('들/Suffix', '의/Josa'),
#  ('의/Josa', '상상력/Noun'),
#  ('상상력/Noun', '은/Josa'),
#  ('은/Josa', '정말/Noun'),
#  ('정말/Noun', '대단한거/Adjective'),
#  ('대단한거/Adjective', '같다는/Adjective'),
#  ('같다는/Adjective', '생각/Noun'),
#  ('생각/Noun', '이/Josa'),
#  ('이/Josa', '든다/Verb'),
#  ('든다/Verb', './Punctuation'),
#  ('./Punctuation', '</s>'),
#  ...]

# %%
print(sentence_ngrams[:10])
# Out:
# [('<s>', '아/Exclamation'), ('아/Exclamation', '더빙/Noun'), ('더빙/Noun', '../Punctuation'), ('../Punctuation', '진짜/Noun'), ('진짜/Noun', '짜증나네요/Adjective'), ('짜증나네요/Adjective', '목소리/Noun'), ('목소리/Noun', '</s>'), ('<s>', '흠/Noun'), ('흠/Noun', '.../Punctuation'), ('.../Punctuation', '포스터/Noun')]

# %% [markdown]
# ##### 4) 조건부 표본 개수

# %% [markdown]
# (1) 조건부 표본 개수

# %%
cfd_ngrams = ConditionalFreqDist(sentence_ngrams) # !!! 입력을 N-gram으로 넣네?

# %%
cfd_ngrams
# Out:
# <ConditionalFreqDist with 105606 conditions>

# %%
cfd_ngrams["<s>"] # !!!
# Out:
# FreqDist({'정말/Noun': 2718, '이/Noun': 2371, '진짜/Noun': 2232, '이/Determiner': 2115, '영화/Noun': 2069, '아/Exclamation': 1693, '너무/Adverb': 1627, '평점/Noun': 1583, '내/Noun': 1542, '최고/Noun': 1127, ...})

# %%
print(cfd_ngrams["<s>"].most_common(5)) # !!!
# Out:
# [('정말/Noun', 2718), ('이/Noun', 2371), ('진짜/Noun', 2232), ('이/Determiner', 2115), ('영화/Noun', 2069)]

# %% [markdown]
# (2) 토큰 C 다음으로 가장 많이 등장하는 N개 단어 반환

# %%
def cfd_most_common(c, n, pos=None):
  if pos is None:
    # print(okt_tokenize(c))
    return cfd_ngrams[okt_tokenize(c)[0]].most_common(n) # [0]을 한 이유는 문장의 가장 처음 형태소만 따오기 위함 # !!!
  else:
    return cfd_ngrams["/".join([c, pos])].most_common(n)

# %%
print(cfd_most_common("나", 10))
# Out:
# [('는/Josa', 831), ('의/Josa', 339), ('만/Josa', 213), ('에게/Josa', 148), ('에겐/Josa', 84), ('랑/Josa', 81), ('한테/Josa', 50), ('참/Verb', 45), ('이/Determiner', 44), ('와도/Josa', 43)]

# %% [markdown]
# ##### 5) 조건부 확률 계산

# %% [markdown]
# (1) 조건부 확률 계산

# %%
cpd_ngrams = ConditionalProbDist(cfd_ngrams, MLEProbDist) # !!!

# %%
cpd_ngrams
# Out:
# <ConditionalProbDist with 105606 conditions>

# %%
cpd_ngrams["<s>"]
# Out:
# <MLEProbDist based on 150000 samples>

# %%
# - “.” 다음에 “</s>”가 올 확률 출력
print(cpd_ngrams[okt_tokenize(".")[0]].prob("</s>")) # !!!
# Out:
# 0.39102658679807606

# %% [markdown]
# (2) 토큰 C 다음으로 토큰 W가 Bigram으로 함께 등장할 확률

# %%
def cpd_bigram_prob(context, next):
  context_okt_token = okt_tokenize(context)[0] # !
  next_okt_token = okt_tokenize(next)[0] # !
  return cpd_ngrams[context_okt_token].prob(next_okt_token) # !

# %%
print(cpd_bigram_prob("이", "영화"))
# Out:
# 0.4010748656417948

# %%
print(cpd_bigram_prob("영화", "이"))
# Out:
# 0.00015767585785521414

# %% [markdown]
# ##### 6) 문장 생성기
# - 조건부 확률 계산 -> 가장 확률이 높은 토큰열 추출 -> 문장 생성

# %%
def generate_sentence(seed=None, debug=False):
  # (1) 시드 초기화
  if seed is not None:
    import random
    random.seed(seed)
  # (2) 변수 초기화
  context = "<s>" # 시작 단어
  sentence = []
  # (3) 문장 생성
  while True:
    # 1] 시작 단어가 사전에 없는 경우 : 문장 생성 중단
    if context not in cpd_ngrams: # !!!
      break
    # 2] 다음 단어 생성
    next_word_pos = cpd_ngrams[context].generate() # !!!
    # 3] 다음 단어가 문장의 마지막인 경우 : 문장 생성 중단
    if next_word_pos == "</s>": # !!
      break
    # 4] 다음 단어 분석
    next_word = next_word_pos.split("/")[0] # !
    next_pos = next_word_pos.split("/")[1] # !
    # 5] 단어 전처리 (조사, 어미 등은 제외하고, 각 토큰은 띄어쓰기로 구분해서 생성)
    if context == "<s>":
      sentence.append(next_word.title()) # !!!
    elif context in ["`", "\"","'","("]: # !!
      sentence.append(next_word)
    elif next_word in ["'", ".", ",", ")", ":", ";", "?"]: # !!
      sentence.append(next_word)
    elif next_pos in ["Josa", "Punctuation", "Suffix"]: # !!!
      sentence.append(next_word)
    elif next_word_pos in ["임/Noun", "것/Noun", "는걸/Noun", "릴때/Noun", "되다/Verb", "이다/Verb", "하다/Verb", "이다/Adjective"]: # !!
      sentence.append(next_word)
    else: # !!
      sentence.append(" " + next_word)
    context = next_word_pos
    # 6] 결과 출력
    if debug:
      print(next_word_pos)

  return "".join(sentence)

# %%
print(generate_sentence(2))
# Out:
# 도리까지 본 영화 너무... 뭔가.. 최고네요. 하지만.. 눈물 낫다는건 또 영화에 들지 않는다. 근데 뭐야 어떻게 그렇게 착했던 윤재랑은 에바 그린 드레스 소리 듣는거임""" 에리 욧의 미모로 합성 한 가수 노래와 흥행 놓친 영화다. 사투리 연기 하나 없는 ‘ 스피드 감 넘치는 스릴 넘치는 연기를 이해 되지 못 하시는 분보다 훨 재밌구만 평점을 망처 놓은 듯하다. 영화 보는이로 하여금 불편함을 느꼇을듯

# %%
generate_sentence(2, debug=True)
# Out:
# 도리/Noun
# 까지/Josa
# 본/Verb
# 영화/Noun
# 너무/Adverb
# .../Punctuation
# 뭔가/Noun
# ../Punctuation
# 최고/Noun
# 네/Suffix
# 요/Josa
# ./Punctuation
# 하지만/Conjunction
# ../Punctuation
# 눈물/Noun
# 낫다는건/Verb
# 또/Noun
# 영화/Noun
# 에/Josa
# 들지/Verb
# 않는다/Verb
# ./Punctuation
# 근데/Adverb
# 뭐/Noun
# 야/Josa
# 어떻게/Adjective
# 그렇게/Adverb
# 착했던/Adjective
# 윤재/Noun
# 랑은/Josa
# 에바/Noun
# 그린/Noun
# 드레스/Noun
# 소리/Noun
# 듣는거/Verb
# 임/Noun
# """/Punctuation
# 에리/Noun
# 욧의/Noun
# 미모/Noun
# 로/Josa
# 합성/Noun
# 한/Determiner
# 가수/Noun
# 노래/Noun
# 와/Josa
# 흥행/Noun
# 놓친/Verb
# 영화/Noun
# 다/Josa
# ./Punctuation
# 사투리/Noun
# 연기/Noun
# 하나/Noun
# 없는/Adjective
# ‘/Foreign
# 스피드/Noun
# 감/Noun
# 넘치는/Adjective
# 스릴/Noun
# 넘치는/Adjective
# 연기/Noun
# 를/Josa
# 이해/Noun
# 되지/Verb
# 못/VerbPrefix
# 하시는/Verb
# 분/Noun
# 보다/Josa
# 훨/Noun
# 재밌구만/Adjective
# 평점/Noun
# 을/Josa
# 망처/Noun
# 놓은/Verb
# 듯/Noun
# 하다/Verb
# ./Punctuation
# 영화/Noun
# 보는이로/Verb
# 하여금/Adverb
# 불편함을/Adjective
# 느꼇을듯/Noun
# '도리까지 본 영화 너무... 뭔가.. 최고네요. 하지만.. 눈물 낫다는건 또 영화에 들지 않는다. 근데 뭐야 어떻게 그렇게 착했던 윤재랑은 에바 그린 드레스 소리 듣는거임""" 에리 욧의 미모로 합성 한 가수 노래와 흥행 놓친 영화다. 사투리 연기 하나 없는 ‘ 스피드 감 넘치는 스릴 넘치는 연기를 이해 되지 못 하시는 분보다 훨 재밌구만 평점을 망처 놓은 듯하다. 영화 보는이로 하여금 불편함을 느꼇을듯'

# %% [markdown]
# ### 5. 결과
# ： 위 예제는 코퍼스 내의 등장 빈도에 기반하여 문장을 생성한다. bigram 언어 모델로 생성한 것이기 때문에 인접한 두 단어는 그나마 자연스럽지만 멀리 떨어진 단어와는 전혀 무관한 모습을 보인다. 또한 생성된 문장의 전체적인 문맥이 부자연스러우며 통사적으로 부적절한 모습도 보인다. 이는 코퍼스 내의 정보만으로 제한된 단어 조합만을 고려하는 N-gram 언어 모델의 한계로 보인다. 위 예제는 단순화를 위해 전처리와 규칙 처리를 최소화하였는데, 데이터셋을 늘리고 한국어 특징에 맞게 전처리를 진행한다면 보다 향상된 결과를 얻을 수 있을 것이다.

# %% [markdown]
# <참고>
#
# > https://datascienceschool.net/view-notebook/a0c848e1e2d343d685e6077c35c4203b/
